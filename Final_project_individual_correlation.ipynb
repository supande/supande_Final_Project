# %%
import csv

f=open('Crime_complaints_2020.csv','r')
reader=csv.reader(f)

n=0
l=[]
for row in reader:
    if n>0:
        crime=row[8]
        if crime!='':
            if crime in l:
                pass
            else:
                l.append(crime)
    n+=1


print(l)
print(len(l))
#f1=open('CovidDailyCases_2020','r')
#reader1=csv.reader(f1)
#d={}
#n=0
#for row in reader1:
#    if n>0:
#        date=row2[0]
#        if 
        
        
        
    
    
#f.close()
# Out:
# ['MURDER & NON-NEGL. MANSLAUGHTER', 'PETIT LARCENY', 'FORGERY', 'ROBBERY', 'HARRASSMENT 2', 'DANGEROUS WEAPONS', 'FELONY ASSAULT', 'THEFT-FRAUD', 'CRIMINAL TRESPASS', 'BURGLARY', 'SEX CRIMES', 'ARSON', 'ASSAULT 3 & RELATED OFFENSES', 'GRAND LARCENY', 'DANGEROUS DRUGS', 'RAPE', 'MISCELLANEOUS PENAL LAW', 'VEHICLE AND TRAFFIC LAWS', 'UNAUTHORIZED USE OF A VEHICLE', 'ADMINISTRATIVE CODE', 'CRIMINAL MISCHIEF & RELATED OF', 'GRAND LARCENY OF MOTOR VEHICLE', 'THEFT OF SERVICES', 'OTHER OFFENSES RELATED TO THEF', 'OFF. AGNST PUB ORD SENSBLTY &', 'OFFENSES INVOLVING FRAUD', 'POSSESSION OF STOLEN PROPERTY', 'OFFENSES AGAINST PUBLIC ADMINI', 'NYS LAWS-UNCLASSIFIED FELONY', "BURGLAR'S TOOLS", 'FRAUDS', 'INTOXICATED & IMPAIRED DRIVING', 'OFFENSES AGAINST THE PERSON', 'PROSTITUTION & RELATED OFFENSES', 'OTHER STATE LAWS (NON PENAL LA', 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'KIDNAPPING & RELATED OFFENSES', 'PETIT LARCENY OF MOTOR VEHICLE', 'OFFENSES AGAINST PUBLIC SAFETY', 'FORTUNE TELLING', 'GAMBLING', 'ANTICIPATORY OFFENSES', 'ALCOHOLIC BEVERAGE CONTROL LAW', 'FELONY SEX CRIMES', 'CHILD ABANDONMENT/NON SUPPORT', 'DISORDERLY CONDUCT', 'OTHER STATE LAWS', 'FRAUDULENT ACCOSTING', 'HOMICIDE-NEGLIGENT,UNCLASSIFIE', 'JOSTLING', 'KIDNAPPING', 'UNLAWFUL POSS. WEAP. ON SCHOOL', 'ESCAPE 3', 'NEW YORK CITY HEALTH CODE', 'ENDAN WELFARE INCOMP', 'NYS LAWS-UNCLASSIFIED VIOLATION', 'HOMICIDE-NEGLIGENT-VEHICLE', 'OFFENSES RELATED TO CHILDREN']
# 58

# %%
'''import csv, datetime
from collections import Counter

f=open('Crime_complaints_2020.csv','r')
reader=csv.reader(f)

d={}
n=0

for row in reader:
    if n>0:
        c=row[8]
        if c in d:
            d[c]+=1
        else:
            d[c]=1
    n+=1

#print(d)
a=Counter(d)
b=a.most_common(20)
#print(b)
f.close()

f1=open('Crime_complaints_2020.csv','r')
reader1=csv.reader(f1)

n=0


l2=[{}]*10
for i in range(0,10):
    l1=[]
    for row in reader1:
    
        if n>0:
            date=row[1]
            if row[8]==b[i][0]:
                if date in l1:
                    l2[i][date]+=1
                else:
                    l1.append(date)
                    l2[i][date]=1
           
        n+=1

print(l2)  
l4=sorted(l1)
f1.close()

f2=open("Crimes_grouping.csv",'w')
writer=csv.writer(f2,delimiter=',',lineterminator='\n')

writer.writerow(['Date',b[0][0],b[1][0],b[2][0],b[3][0],b[4][0],b[5][0],b[6][0],b[7][0],b[8][0],b[9][0]])

for i in l4:
    l3=[]
    l3.append(i)
    
    for j in l2:
        
        for k in j.keys():
            if i==k:
                l3.append(j[k])
        
    writer.writerow(l3)
                
f2.close()            
        
n=0
crimes={}
for row in reader:
    if n>0:
        date=row[1]
        crime=row[8]
        if crime not in crimes:
            crimes[crime]={}
        if date in crimes[crime]:
            crimes[crime][date]+=1
        else:
            crimes[crime][date]=1
    n+=1
        
print(crimes)  
        
'''
# Out:
# [{'11/14/2020': 234, '10/31/2020': 191, '11/05/2020': 271, '11/09/2020': 217, '11/07/2020': 230, '09/29/2020': 238, '09/20/2020': 201, '09/23/2020': 238, '09/18/2020': 247, '09/21/2020': 233, '08/30/2020': 198, '09/07/2020': 229, '08/27/2020': 234, '06/22/2020': 211, '07/10/2020': 254, '05/31/2020': 156, '04/25/2020': 172, '05/09/2020': 211, '05/06/2020': 176, '04/04/2020': 144, '04/11/2020': 150, '03/06/2020': 214, '12/21/2020': 219, '12/26/2020': 173, '06/30/2020': 240, '12/13/2020': 207, '03/15/2020': 215, '12/28/2020': 191, '10/24/2020': 230, '12/11/2020': 238, '12/31/2020': 93, '12/23/2020': 197, '12/25/2020': 105, '12/18/2020': 224, '12/24/2020': 200, '12/19/2020': 194, '12/22/2020': 222, '12/10/2020': 244, '12/30/2020': 149, '12/02/2020': 244, '12/16/2020': 214, '11/04/2020': 246, '12/27/2020': 147, '12/29/2020': 178, '09/30/2020': 246, '09/09/2020': 242, '12/08/2020': 248, '12/20/2020': 192, '03/29/2020': 135, '11/24/2020': 202, '06/25/2020': 218, '12/15/2020': 227, '12/14/2020': 243, '12/03/2020': 235, '05/23/2020': 195, '11/03/2020': 213, '12/17/2020': 161, '12/04/2020': 243, '08/22/2020': 226, '12/12/2020': 211, '10/13/2020': 260, '10/09/2020': 262, '12/01/2020': 268, '12/07/2020': 250, '11/27/2020': 255, '12/09/2020': 241, '11/16/2020': 252, '10/27/2020': 294, '05/12/2020': 199, '06/03/2020': 176, '09/06/2020': 204, '10/28/2020': 256, '11/01/2020': 196, '07/01/2020': 230, '09/27/2020': 206, '11/18/2020': 220, '03/24/2020': 156, '11/21/2020': 230, '12/05/2020': 224, '11/15/2020': 201, '12/06/2020': 203, '10/22/2020': 256, '10/04/2020': 181, '03/22/2020': 141, '03/21/2020': 171, '08/16/2020': 223, '08/25/2020': 290, '04/29/2020': 185, '07/31/2020': 206, '03/09/2020': 261, '08/02/2020': 218, '11/29/2020': 203, '11/26/2020': 145, '03/10/2020': 272, '08/19/2020': 249, '05/14/2020': 212
    dates.append(dt)
'''

# %%
import csv, datetime

f=open("CovidDailyCases_2020.csv",'r')
reader1=csv.reader(f)

count_cases_per_day=[]
n=0
for row in reader1:
    if n>0:
        cases=row[1]
        count_cases_per_day.append(cases)
        
    n+=1
#print(count_crimes_per_day)
'''
dates=[]
for k in count_crimes_per_day.keys():
    dates.append(k)
    
#print(dates)
    
'''
    
f1=open('Crime_complaints_2020.csv','r')
reader=csv.reader(f1)

f2=open('Crime_Grouping.csv','w')
writer=csv.writer(f2,delimiter=',',lineterminator='\n')

n=0
crimes={}
for row in reader:
    if n>0:
        date=row[1]
        crime=row[8]
        if crime!='':
            if crime not in crimes:
                crimes[crime]={}
            if date in crimes[crime]:
                crimes[crime][date]+=1
            else:
                crimes[crime][date]=1
    n+=1
#print(crimes)
    

base = datetime.datetime.strptime('03/01/2020','%m/%d/%Y')
date_list = [base + datetime.timedelta(days=x) for x in range(306)]
dates=[]
for i in date_list:
    dt=datetime.datetime.strftime(i,'%m/%d/%Y')
    dt1=dt.split
    dates.append(dt)

#print(dates)    
    
n=0
crime_list=[]

for i in crimes.keys():
    crime_list.append(i)
    
crime_list.insert(0,'Date')
crime_list.insert(1,'Total Covid Cases')

writer.writerow(crime_list)
list_final=[]
for date in dates:
    row=[]
    for crime in crimes.keys():
        if crimes[crime].get(date) is None:
            row.append(0)
        else:
            row.append(crimes[crime].get(date))
    
    row.insert(0,date)
    #row.insert(1,count_crimes_per_day[date])
    #writer.writerow(row)
    list_final.append(row)
    #print(row)
    
    n+=1

m=0
for elements in list_final:
    elements.insert(1,count_cases_per_day[m])
    writer.writerow(elements)
    m+=1

#print(list_final)

#for elements in list_final:
    #writer.writerow(row)
    

f.close()           
f1.close() 
f2.close()

# %%
import csv

f=open('Crime_complaints_2021.csv','r')
reader=csv.reader(f)

n=0
l=[]
for row in reader:
    if n>0:
        crime=row[15]
        if crime!='':
            if crime in l:
                pass
            else:
                l.append(crime)
    n+=1


print(l)
print(len(l))
# Out:
# ['MURDER & NON-NEGL. MANSLAUGHTER', 'DANGEROUS WEAPONS', 'PETIT LARCENY', 'ROBBERY', 'HARRASSMENT 2', 'OFFENSES AGAINST PUBLIC ADMINI', 'ASSAULT 3 & RELATED OFFENSES', 'FELONY ASSAULT', 'SEX CRIMES', 'GRAND LARCENY', 'CRIMINAL MISCHIEF & RELATED OF', 'OFFENSES INVOLVING FRAUD', 'BURGLARY', 'OFFENSES AGAINST THE PERSON', 'GRAND LARCENY OF MOTOR VEHICLE', 'INTOXICATED & IMPAIRED DRIVING', 'MISCELLANEOUS PENAL LAW', 'OTHER OFFENSES RELATED TO THEF', 'RAPE', 'THEFT-FRAUD', 'OFF. AGNST PUB ORD SENSBLTY &', 'DANGEROUS DRUGS', 'VEHICLE AND TRAFFIC LAWS', 'FORGERY', 'UNAUTHORIZED USE OF A VEHICLE', 'CRIMINAL TRESPASS', 'PETIT LARCENY OF MOTOR VEHICLE', 'POSSESSION OF STOLEN PROPERTY', 'FRAUDS', 'OTHER STATE LAWS (NON PENAL LA', 'ARSON', "BURGLAR'S TOOLS", 'KIDNAPPING & RELATED OFFENSES', 'NYS LAWS-UNCLASSIFIED FELONY', 'HOMICIDE-NEGLIGENT,UNCLASSIFIE', 'THEFT OF SERVICES', 'ADMINISTRATIVE CODE', 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'GAMBLING', 'FRAUDULENT ACCOSTING', 'NYS LAWS-UNCLASSIFIED VIOLATION', 'OFFENSES AGAINST PUBLIC SAFETY', 'CHILD ABANDONMENT/NON SUPPORT', 'ENDAN WELFARE INCOMP', 'FELONY SEX CRIMES', 'PROSTITUTION & RELATED OFFENSES', 'ALCOHOLIC BEVERAGE CONTROL LAW', 'DISORDERLY CONDUCT', 'ANTICIPATORY OFFENSES', 'JOSTLING', 'HOMICIDE-NEGLIGENT-VEHICLE', 'LOITERING/GAMBLING (CARDS, DIC', 'ESCAPE 3', 'KIDNAPPING', 'OFFENSES RELATED TO CHILDREN', 'OTHER STATE LAWS', 'DISRUPTION OF A RELIGIOUS SERV', 'OTHER STATE LAWS (NON PENAL LAW)', 'INTOXICATED/IMPAIRED DRIVING', 'OFFENSES AGAINST MARRIAGE UNCL', 'NEW YORK CITY HEALTH CODE']
# 61

# %%
import csv, datetime

f=open("CovidDailyCases_2021.csv",'r')
reader1=csv.reader(f)

count_cases_per_day=[]
n=0
for row in reader1:
    if n>0:
        cases=row[0]
        count_cases_per_day.append(cases)
        
    n+=1
#print(count_crimes_per_day)
'''
dates=[]
for k in count_crimes_per_day.keys():
    dates.append(k)
    
#print(dates)
    
'''
    
f1=open('Crime_complaints_2021.csv','r')
reader=csv.reader(f1)

f2=open('Crime_Grouping_2021.csv','w')
writer=csv.writer(f2,delimiter=',',lineterminator='\n')

n=0
crimes={}
for row in reader:
    if n>0:
        date=row[3]
        crime=row[15]
        if crime!='':
            if crime not in crimes:
                crimes[crime]={}
            if date in crimes[crime]:
                crimes[crime][date]+=1
            else:
                crimes[crime][date]=1
    n+=1
#print(crimes)
    

base = datetime.datetime.strptime('01/01/2021','%m/%d/%Y')
date_list = [base + datetime.timedelta(days=x) for x in range(273)]
dates=[]
for i in date_list:
    dt=datetime.datetime.strftime(i,'%m/%d/%Y')
    dt1=dt.split
    dates.append(dt)

#print(dates)    
    
n=0
crime_list=[]

for i in crimes.keys():
    crime_list.append(i)
    
crime_list.insert(0,'Date')
crime_list.insert(1,'Total Covid Cases')

writer.writerow(crime_list)
list_final=[]
for date in dates:
    row=[]
    for crime in crimes.keys():
        if crimes[crime].get(date) is None:
            row.append(0)
        else:
            row.append(crimes[crime].get(date))
    
    row.insert(0,date)
    #row.insert(1,count_crimes_per_day[date])
    #writer.writerow(row)
    list_final.append(row)
    #print(row)
    
    n+=1

m=0
for elements in list_final:
    elements.insert(1,count_cases_per_day[m])
    writer.writerow(elements)
    m+=1

#print(list_final)

#for elements in list_final:
    #writer.writerow(row)
    

f.close()           
f1.close() 
f2.close()
