# %%
import csv,datetime
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(17, 8), dpi=80)

f=open("NumberOfCrimesPerDay_2020_2.csv",'r')
reader=csv.reader(f)
       
n=0
d={}
jan=0
feb=0
mar=0
apr=0
may=0
jun=0
jul=0
aug=0
sep=0
octo=0
nov=0
dec=0

for row in reader:
       if n>0:
           date=row[0]
           dto=datetime.datetime.strptime(date,"%m/%d/%Y")
           num=int(row[1])
        
           if dto<datetime.datetime.strptime('02/01/2020',"%m/%d/%Y"):
               jan+=num
                
           elif dto<datetime.datetime.strptime('03/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('01/31/2020',"%m/%d/%Y"):
               feb+=num
                
           elif dto<datetime.datetime.strptime('04/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('02/29/2020',"%m/%d/%Y"):
               mar+=num
       
           elif dto<datetime.datetime.strptime('05/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('03/31/2020',"%m/%d/%Y"):
               apr+=num
       
           elif dto<datetime.datetime.strptime('06/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('04/30/2020',"%m/%d/%Y"):
               may+=num
       
           elif dto<datetime.datetime.strptime('07/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('05/31/2020',"%m/%d/%Y"):
               jun+=num
       
           elif dto<datetime.datetime.strptime('08/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('06/30/2020',"%m/%d/%Y"):
               jul+=num
       
           elif dto<datetime.datetime.strptime('09/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('07/31/2020',"%m/%d/%Y"):
               aug+=num
       
           elif dto<datetime.datetime.strptime('10/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('08/31/2020',"%m/%d/%Y"):
               sep+=num
       
           elif dto<datetime.datetime.strptime('11/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('09/30/2020',"%m/%d/%Y"):
               octo+=num
       
           elif dto<datetime.datetime.strptime('12/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('10/31/2020',"%m/%d/%Y"):
               nov+=num
       
           elif dto>datetime.datetime.strptime('11/30/2020',"%m/%d/%Y"):
               dec+=num
       n+=1
d["Jan"]=jan//31
d["Feb"]=feb//29
d["March"]=mar//31
d["April"]=apr//30
d["May"]=may//31
d["June"]=jun//30           
d["July"]=jul//31
d["August"]=aug//31       
d["Sept"]=sep//30
d["Oct"]=octo//31      
d["Nov"]=nov//30
d["Dec"]=dec//31
       
#print(d)
'''
plt.bar(range(len(d)), d.values(), align='center')
plt.xticks(range(len(d)), list(d.keys()))
plt.xlabel('Month')
plt.ylabel('Average number of crimes per day')
plt.title('2020 Summary')
#plt.show()
plt.savefig('2020_AverageCrimes_by_month.png')
'''

f.close()


f1=open("NumberOfCrimesPerDay_2019.csv",'r')
reader1=csv.reader(f1)
       
n=0
d1={}
jan=0
feb=0
mar=0
apr=0
may=0
jun=0
jul=0
aug=0
sep=0
octo=0
nov=0
dec=0

for row in reader1:
       if n>0:
           date=row[0]
           dto=datetime.datetime.strptime(date,"%m/%d/%Y")
           num=int(row[1])
        
           if dto<datetime.datetime.strptime('02/01/2019',"%m/%d/%Y"):
               jan+=num
                
           elif dto<datetime.datetime.strptime('03/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('01/31/2019',"%m/%d/%Y"):
               feb+=num
                
           elif dto<datetime.datetime.strptime('04/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('02/28/2019',"%m/%d/%Y"):
               mar+=num
       
           elif dto<datetime.datetime.strptime('05/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('03/31/2019',"%m/%d/%Y"):
               apr+=num
       
           elif dto<datetime.datetime.strptime('06/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('04/30/2019',"%m/%d/%Y"):
               may+=num
       
           elif dto<datetime.datetime.strptime('07/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('05/31/2019',"%m/%d/%Y"):
               jun+=num
       
           elif dto<datetime.datetime.strptime('08/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('06/30/2019',"%m/%d/%Y"):
               jul+=num
       
           elif dto<datetime.datetime.strptime('09/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('07/31/2019',"%m/%d/%Y"):
               aug+=num
       
           elif dto<datetime.datetime.strptime('10/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('08/31/2019',"%m/%d/%Y"):
               sep+=num
       
           elif dto<datetime.datetime.strptime('11/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('09/30/2019',"%m/%d/%Y"):
               octo+=num
       
           elif dto<datetime.datetime.strptime('12/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('10/31/2019',"%m/%d/%Y"):
               nov+=num
       
           elif dto>datetime.datetime.strptime('11/30/2019',"%m/%d/%Y"):
               dec+=num
       n+=1
d1["Jan"]=jan//31
d1["Feb"]=feb//28
d1["March"]=mar//31
d1["April"]=apr//30
d1["May"]=may//31
d1["June"]=jun//30           
d1["July"]=jul//31
d1["August"]=aug//31       
d1["Sept"]=sep//30
d1["Oct"]=octo//31      
d1["Nov"]=nov//30
d1["Dec"]=dec//31

plt.bar(range(len(d1)), d1.values(), align='center')
plt.xticks(range(len(d1)), list(d1.keys()))
plt.xlabel('Month')
plt.ylabel('Average number of crimes per day')
plt.title('2019 Summary')
#plt.show()
plt.savefig('2019_AverageCrimes_by_month.png')
       
#print(d1)

d_19_20={}

d_19_20["January"]=d1["Jan"]-d["Jan"]
d_19_20["February"]=d1["Feb"]-d["Feb"]
d_19_20["March"]=d1["March"]-d["March"]
d_19_20["April"]=d1["April"]-d["April"]
d_19_20["May"]=d1["May"]-d["May"]
d_19_20["June"]=d1["June"]-d["June"]    
d_19_20["July"]=d1["July"]-d["July"]
d_19_20["August"]=d1["August"]-d["August"]    
d_19_20["September"]=d1["Sept"]-d["Sept"]
d_19_20["October"]=d1["Oct"]-d["Oct"]
d_19_20["November"]=d1["Nov"]-d["Nov"]
d_19_20["December"]=d1["Dec"]-d["Dec"]

print("Month  |  Difference")
print("--------|------------")
print("January","|",d_19_20["January"])
print("February","|",d_19_20["February"])
print("March","|",d_19_20["March"])
print("April","|",d_19_20["April"])
print("May","|",d_19_20["May"])
print("June","|",d_19_20["June"])
print("July","|",d_19_20["July"])
print("August","|",d_19_20["August"])
print("September","|",d_19_20["September"])
print("October","|",d_19_20["October"])
print("November","|",d_19_20["November"])
print("December","|",d_19_20["December"])
#print(d_19_20)

f1.close()
# Out:
# Month  |  Difference
# --------|------------
# January | -77
# February | -81
# March | 129
# April | 387
# May | 265
# June | 249
# July | 225
# August | 121
# September | 154
# October | 96
# November | 99
# December | 191

# %%
import csv,datetime
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(17, 8), dpi=80)

f=open("NumberOfCrimesPerDay_2019.csv",'r')
reader=csv.reader(f)
       
n=0
d={}
mar=0
apr=0
may=0
jun=0
jul=0
aug=0
sep=0
octo=0
nov=0
dec=0

for row in reader:
       if n>0:
           date=row[0]
           dto=datetime.datetime.strptime(date,"%m/%d/%Y")
           num=int(row[1])
           if dto<datetime.datetime.strptime('04/01/2019',"%m/%d/%Y"):
               mar+=num
       
           elif dto<datetime.datetime.strptime('05/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('03/31/2019',"%m/%d/%Y"):
               apr+=num
       
           elif dto<datetime.datetime.strptime('06/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('04/30/2019',"%m/%d/%Y"):
               may+=num
       
           elif dto<datetime.datetime.strptime('07/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('05/31/2019',"%m/%d/%Y"):
               jun+=num
       
           elif dto<datetime.datetime.strptime('08/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('06/30/2019',"%m/%d/%Y"):
               jul+=num
       
           elif dto<datetime.datetime.strptime('09/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('07/31/2019',"%m/%d/%Y"):
               aug+=num
       
           elif dto<datetime.datetime.strptime('10/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('08/31/2019',"%m/%d/%Y"):
               sep+=num
       
           elif dto<datetime.datetime.strptime('11/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('09/30/2019',"%m/%d/%Y"):
               octo+=num
       
           elif dto<datetime.datetime.strptime('12/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('10/31/2019',"%m/%d/%Y"):
               nov+=num
       
           elif dto>datetime.datetime.strptime('11/30/2019',"%m/%d/%Y"):
               dec+=num
       n+=1

d["March"]=mar//31
d["April"]=apr//30
d["May"]=may//31
d["June"]=jun//30           
d["July"]=jul//31
d["August"]=aug//31       
d["Sept"]=sep//30
d["Oct"]=octo//31      
d["Nov"]=nov//30
d["Dec"]=dec//31
       
#print(d)

plt.bar(range(len(d)), d.values(), align='center')
plt.xticks(range(len(d)), list(d.keys()))
plt.xlabel('Month')
plt.ylabel('Average number of crimes per day')
plt.title('2019 Summary')
#plt.show()
plt.savefig('2019_AverageCrimes_by_month.png')

f.close()


f1=open("NumberOfCrimesPerDay_2017.csv",'r')
reader1=csv.reader(f1)
       
n=0
d1={}
mar=0
apr=0
may=0
jun=0
jul=0
aug=0
sep=0
octo=0
nov=0
dec=0

for row in reader1:
       if n>0:
           date=row[0]
           dto=datetime.datetime.strptime(date,"%m/%d/%Y")
           num=int(row[1])
           if dto<datetime.datetime.strptime('04/01/2017',"%m/%d/%Y"):
               mar+=num
       
           elif dto<datetime.datetime.strptime('05/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('03/31/2017',"%m/%d/%Y"):
               apr+=num
       
           elif dto<datetime.datetime.strptime('06/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('04/30/2017',"%m/%d/%Y"):
               may+=num
       
           elif dto<datetime.datetime.strptime('07/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('05/31/2017',"%m/%d/%Y"):
               jun+=num
       
           elif dto<datetime.datetime.strptime('08/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('06/30/2017',"%m/%d/%Y"):
               jul+=num
       
           elif dto<datetime.datetime.strptime('09/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('07/31/2017',"%m/%d/%Y"):
               aug+=num
       
           elif dto<datetime.datetime.strptime('10/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('08/31/2017',"%m/%d/%Y"):
               sep+=num
       
           elif dto<datetime.datetime.strptime('11/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('09/30/2017',"%m/%d/%Y"):
               octo+=num
       
           elif dto<datetime.datetime.strptime('12/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('10/31/2017',"%m/%d/%Y"):
               nov+=num
       
           elif dto>datetime.datetime.strptime('11/30/2017',"%m/%d/%Y"):
               dec+=num
       n+=1

d1["March"]=mar//31
d1["April"]=apr//30
d1["May"]=may//31
d1["June"]=jun//30           
d1["July"]=jul//31
d1["August"]=aug//31       
d1["Sept"]=sep//30
d1["Oct"]=octo//31      
d1["Nov"]=nov//30
d1["Dec"]=dec//31
       
#print(d1)

d_17_19={}

d_17_19["March difference"]=d1["March"]-d["March"]
d_17_19["April difference"]=d1["April"]-d["April"]
d_17_19["May difference"]=d1["May"]-d["May"]
d_17_19["June difference"]=d1["June"]-d["June"]    
d_17_19["July difference"]=d1["July"]-d["July"]
d_17_19["August difference"]=d1["August"]-d["August"]    
d_17_19["Sept difference"]=d1["Sept"]-d["Sept"]
d_17_19["Oct difference"]=d1["Oct"]-d["Oct"]
d_17_19["Nov difference"]=d1["Nov"]-d["Nov"]
d_17_19["Dec difference"]=d1["Dec"]-d["Dec"]

#print(d_17_19)

f1.close()

# %%
import csv,datetime
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(17, 8), dpi=80)

f=open("NumberOfCrimesPerDay_2017.csv",'r')
reader=csv.reader(f)
       
n=0
d={}
mar=0
apr=0
may=0
jun=0
jul=0
aug=0
sep=0
octo=0
nov=0
dec=0

for row in reader:
       if n>0:
           date=row[0]
           dto=datetime.datetime.strptime(date,"%m/%d/%Y")
           num=int(row[1])
           if dto<datetime.datetime.strptime('04/01/2017',"%m/%d/%Y"):
               mar+=num
       
           elif dto<datetime.datetime.strptime('05/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('03/31/2017',"%m/%d/%Y"):
               apr+=num
       
           elif dto<datetime.datetime.strptime('06/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('04/30/2017',"%m/%d/%Y"):
               may+=num
       
           elif dto<datetime.datetime.strptime('07/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('05/31/2017',"%m/%d/%Y"):
               jun+=num
       
           elif dto<datetime.datetime.strptime('08/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('06/30/2017',"%m/%d/%Y"):
               jul+=num
       
           elif dto<datetime.datetime.strptime('09/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('07/31/2017',"%m/%d/%Y"):
               aug+=num
       
           elif dto<datetime.datetime.strptime('10/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('08/31/2017',"%m/%d/%Y"):
               sep+=num
       
           elif dto<datetime.datetime.strptime('11/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('09/30/2017',"%m/%d/%Y"):
               octo+=num
       
           elif dto<datetime.datetime.strptime('12/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('10/31/2017',"%m/%d/%Y"):
               nov+=num
       
           elif dto>datetime.datetime.strptime('11/30/2017',"%m/%d/%Y"):
               dec+=num
       n+=1

d["March"]=mar//31
d["April"]=apr//30
d["May"]=may//31
d["June"]=jun//30           
d["July"]=jul//31
d["August"]=aug//31       
d["Sept"]=sep//30
d["Oct"]=octo//31      
d["Nov"]=nov//30
d["Dec"]=dec//31
       
#print(d)

plt.bar(range(len(d)), d.values(), align='center')
plt.xticks(range(len(d)), list(d.keys()))
plt.xlabel('Month')
plt.ylabel('Average number of crimes per day')
plt.title('2017 Summary')
#plt.show()
plt.savefig('2017_AverageCrimes_by_month.png')

f.close()

# %%
import csv,datetime
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(17, 8), dpi=80)

f=open("NumberOfCrimesPerDay_2017.csv",'r')
reader=csv.reader(f)
       
n=0
d={}
jan=0
feb=0
mar=0
apr=0
may=0
jun=0
jul=0
aug=0
sep=0
octo=0
nov=0
dec=0

for row in reader:
       if n>0:
           date=row[0]
           dto=datetime.datetime.strptime(date,"%m/%d/%Y")
           num=int(row[1])
        
           if dto<datetime.datetime.strptime('02/01/2017',"%m/%d/%Y"):
               jan+=num
                
           elif dto<datetime.datetime.strptime('03/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('01/31/2017',"%m/%d/%Y"):
               feb+=num
                
           elif dto<datetime.datetime.strptime('04/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('02/28/2017',"%m/%d/%Y"):
               mar+=num
       
           elif dto<datetime.datetime.strptime('05/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('03/31/2017',"%m/%d/%Y"):
               apr+=num
       
           elif dto<datetime.datetime.strptime('06/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('04/30/2017',"%m/%d/%Y"):
               may+=num
       
           elif dto<datetime.datetime.strptime('07/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('05/31/2017',"%m/%d/%Y"):
               jun+=num
       
           elif dto<datetime.datetime.strptime('08/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('06/30/2017',"%m/%d/%Y"):
               jul+=num
       
           elif dto<datetime.datetime.strptime('09/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('07/31/2017',"%m/%d/%Y"):
               aug+=num
       
           elif dto<datetime.datetime.strptime('10/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('08/31/2017',"%m/%d/%Y"):
               sep+=num
       
           elif dto<datetime.datetime.strptime('11/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('09/30/2017',"%m/%d/%Y"):
               octo+=num
       
           elif dto<datetime.datetime.strptime('12/01/2017',"%m/%d/%Y") and dto>datetime.datetime.strptime('10/31/2017',"%m/%d/%Y"):
               nov+=num
       
           elif dto>datetime.datetime.strptime('11/30/2017',"%m/%d/%Y"):
               dec+=num
       n+=1
d["Jan"]=jan//31
d["Feb"]=feb//28
d["March"]=mar//31
d["April"]=apr//30
d["May"]=may//31
d["June"]=jun//30           
d["July"]=jul//31
d["August"]=aug//31       
d["Sept"]=sep//30
d["Oct"]=octo//31      
d["Nov"]=nov//30
d["Dec"]=dec//31
       
#print(d)

plt.bar(range(len(d)), d.values(), align='center')
plt.xticks(range(len(d)), list(d.keys()))
plt.xlabel('Month')
plt.ylabel('Average number of crimes per day')
plt.title('2017 Summary')
#plt.show()
plt.savefig('2017_AverageCrimes_by_month.png')


f.close()


f1=open("NumberOfCrimesPerDay_2019.csv",'r')
reader1=csv.reader(f1)
       
n=0
d1={}
jan=0
feb=0
mar=0
apr=0
may=0
jun=0
jul=0
aug=0
sep=0
octo=0
nov=0
dec=0

for row in reader1:
       if n>0:
           date=row[0]
           dto=datetime.datetime.strptime(date,"%m/%d/%Y")
           num=int(row[1])
        
           if dto<datetime.datetime.strptime('02/01/2019',"%m/%d/%Y"):
               jan+=num
                
           elif dto<datetime.datetime.strptime('03/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('01/31/2019',"%m/%d/%Y"):
               feb+=num
                
           elif dto<datetime.datetime.strptime('04/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('02/28/2019',"%m/%d/%Y"):
               mar+=num
       
           elif dto<datetime.datetime.strptime('05/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('03/31/2019',"%m/%d/%Y"):
               apr+=num
       
           elif dto<datetime.datetime.strptime('06/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('04/30/2019',"%m/%d/%Y"):
               may+=num
       
           elif dto<datetime.datetime.strptime('07/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('05/31/2019',"%m/%d/%Y"):
               jun+=num
       
           elif dto<datetime.datetime.strptime('08/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('06/30/2019',"%m/%d/%Y"):
               jul+=num
       
           elif dto<datetime.datetime.strptime('09/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('07/31/2019',"%m/%d/%Y"):
               aug+=num
       
           elif dto<datetime.datetime.strptime('10/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('08/31/2019',"%m/%d/%Y"):
               sep+=num
       
           elif dto<datetime.datetime.strptime('11/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('09/30/2019',"%m/%d/%Y"):
               octo+=num
       
           elif dto<datetime.datetime.strptime('12/01/2019',"%m/%d/%Y") and dto>datetime.datetime.strptime('10/31/2019',"%m/%d/%Y"):
               nov+=num
       
           elif dto>datetime.datetime.strptime('11/30/2019',"%m/%d/%Y"):
               dec+=num
       n+=1
d1["Jan"]=jan//31
d1["Feb"]=feb//28
d1["March"]=mar//31
d1["April"]=apr//30
d1["May"]=may//31
d1["June"]=jun//30           
d1["July"]=jul//31
d1["August"]=aug//31       
d1["Sept"]=sep//30
d1["Oct"]=octo//31      
d1["Nov"]=nov//30
d1["Dec"]=dec//31
'''
plt.bar(range(len(d1)), d1.values(), align='center')
plt.xticks(range(len(d1)), list(d1.keys()))
plt.xlabel('Month')
plt.ylabel('Average number of crimes per day')
plt.title('2019 Summary')
#plt.show()
plt.savefig('2019_AverageCrimes_by_month.png')
'''       
#print(d1)

d_17_19={}

d_17_19["January"]=d["Jan"]-d1["Jan"]
d_17_19["February"]=d["Feb"]-d1["Feb"]
d_17_19["March"]=d["March"]-d1["March"]
d_17_19["April"]=d["April"]-d1["April"]
d_17_19["May"]=d["May"]-d1["May"]
d_17_19["June"]=d["June"]-d1["June"]    
d_17_19["July"]=d["July"]-d1["July"]
d_17_19["August"]=d["August"]-d1["August"]    
d_17_19["September"]=d["Sept"]-d1["Sept"]
d_17_19["October"]=d["Oct"]-d1["Oct"]
d_17_19["November"]=d["Nov"]-d1["Nov"]
d_17_19["December"]=d["Dec"]-d1["Dec"]

print("Month  |  Difference")
print("--------|------------")
print("January","|",d_17_19["January"])
print("February","|",d_17_19["February"])
print("March","|",d_17_19["March"])
print("April","|",d_17_19["April"])
print("May","|",d_17_19["May"])
print("June","|",d_17_19["June"])
print("July","|",d_17_19["July"])
print("August","|",d_17_19["August"])
print("September","|",d_17_19["September"])
print("October","|",d_17_19["October"])
print("November","|",d_17_19["November"])
print("December","|",d_17_19["December"])
#print(d_19_20)

f1.close()
# Out:
# Month  |  Difference
# --------|------------
# January | -4
# February | -38
# March | -83
# April | -42
# May | -78
# June | -81
# July | -108
# August | -73
# September | -99
# October | -45
# November | -96
# December | -165

# %%
import csv,datetime
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(17, 8), dpi=80)

f=open("NumberOfCrimesPerDay_2020_2.csv",'r')
reader=csv.reader(f)
       
n=0
d={}
jan=0
feb=0
mar=0
apr=0
may=0
jun=0
jul=0
aug=0
sep=0

for row in reader:
       if n>0:
           date=row[0]
           dto=datetime.datetime.strptime(date,"%m/%d/%Y")
           num=int(row[1])
        
           if dto<datetime.datetime.strptime('02/01/2020',"%m/%d/%Y"):
               jan+=num
                
           elif dto<datetime.datetime.strptime('03/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('01/31/2020',"%m/%d/%Y"):
               feb+=num
                
           elif dto<datetime.datetime.strptime('04/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('02/29/2020',"%m/%d/%Y"):
               mar+=num
       
           elif dto<datetime.datetime.strptime('05/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('03/31/2020',"%m/%d/%Y"):
               apr+=num
       
           elif dto<datetime.datetime.strptime('06/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('04/30/2020',"%m/%d/%Y"):
               may+=num
       
           elif dto<datetime.datetime.strptime('07/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('05/31/2020',"%m/%d/%Y"):
               jun+=num
       
           elif dto<datetime.datetime.strptime('08/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('06/30/2020',"%m/%d/%Y"):
               jul+=num
       
           elif dto<datetime.datetime.strptime('09/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('07/31/2020',"%m/%d/%Y"):
               aug+=num
       
           elif dto<datetime.datetime.strptime('10/01/2020',"%m/%d/%Y") and dto>datetime.datetime.strptime('08/31/2020',"%m/%d/%Y"):
               sep+=num
       

       n+=1

d["Jan"]=jan//31
d["Feb"]=feb//29
d["March"]=mar//31
d["April"]=apr//30
d["May"]=may//31
d["June"]=jun//30           
d["July"]=jul//31
d["August"]=aug//31       
d["Sept"]=sep//30
       
#print(d)
'''
plt.bar(range(len(d)), d.values(), align='center')
plt.xticks(range(len(d)), list(d.keys()))
plt.xlabel('Month')
plt.ylabel('Average number of crimes per day')
plt.title('2020 Summary')
#plt.show()
plt.savefig('2020_AverageCrimes_by_month.png')
'''

f.close()


f1=open("NumberOfCrimesPerDay_2021.csv",'r')
reader1=csv.reader(f1)
       
n=0
d1={}
jan=0
feb=0
mar=0
apr=0
may=0
jun=0
jul=0
aug=0
sep=0

for row in reader1:
       if n>0:
           date=row[0]
           dto=datetime.datetime.strptime(date,"%m/%d/%Y")
           num=int(row[1])
        
           if dto<datetime.datetime.strptime('02/01/2021',"%m/%d/%Y"):
               jan+=num
                
           elif dto<datetime.datetime.strptime('03/01/2021',"%m/%d/%Y") and dto>datetime.datetime.strptime('01/31/2019',"%m/%d/%Y"):
               feb+=num
                
           elif dto<datetime.datetime.strptime('04/01/2021',"%m/%d/%Y") and dto>datetime.datetime.strptime('02/28/2019',"%m/%d/%Y"):
               mar+=num
       
           elif dto<datetime.datetime.strptime('05/01/2021',"%m/%d/%Y") and dto>datetime.datetime.strptime('03/31/2019',"%m/%d/%Y"):
               apr+=num
       
           elif dto<datetime.datetime.strptime('06/01/2021',"%m/%d/%Y") and dto>datetime.datetime.strptime('04/30/2019',"%m/%d/%Y"):
               may+=num
       
           elif dto<datetime.datetime.strptime('07/01/2021',"%m/%d/%Y") and dto>datetime.datetime.strptime('05/31/2019',"%m/%d/%Y"):
               jun+=num
       
           elif dto<datetime.datetime.strptime('08/01/2021',"%m/%d/%Y") and dto>datetime.datetime.strptime('06/30/2019',"%m/%d/%Y"):
               jul+=num
       
           elif dto<datetime.datetime.strptime('09/01/2021',"%m/%d/%Y") and dto>datetime.datetime.strptime('07/31/2019',"%m/%d/%Y"):
               aug+=num
       
           elif dto<datetime.datetime.strptime('10/01/2021',"%m/%d/%Y") and dto>datetime.datetime.strptime('08/31/2019',"%m/%d/%Y"):
               sep+=num
       
       n+=1

d1["Jan"]=jan//31
d1["Feb"]=feb//28
d1["March"]=mar//31
d1["April"]=apr//30
d1["May"]=may//31
d1["June"]=jun//30           
d1["July"]=jul//31
d1["August"]=aug//31       
d1["Sept"]=sep//30

plt.bar(range(len(d1)), d1.values(), align='center')
plt.xticks(range(len(d1)), list(d1.keys()))
plt.xlabel('Month')
plt.ylabel('Average number of crimes per day')
plt.title('2021 Summary')
#plt.show()
plt.savefig('2021_AverageCrimes_by_month.png')
       
#print(d1)

d_20_21={}

d_20_21["January"]=d["Jan"]-d1["Jan"]
d_20_21["February"]=d["Feb"]-d1["Feb"]
d_20_21["March"]=d["March"]-d1["March"]
d_20_21["April"]=d["April"]-d1["April"]
d_20_21["May"]=d["May"]-d1["May"]
d_20_21["June"]=d["June"]-d1["June"]    
d_20_21["July"]=d["July"]-d1["July"]
d_20_21["August"]=d["August"]-d1["August"]    
d_20_21["September"]=d["Sept"]-d1["Sept"]

print("Month  |  Difference")
print("--------|------------")
print("January","|",d_20_21["January"])
print("February","|",d_20_21["February"])
print("March","|",d_20_21["March"])
print("April","|",d_20_21["April"])
print("May","|",d_20_21["May"])
print("June","|",d_20_21["June"])
print("July","|",d_20_21["July"])
print("August","|",d_20_21["August"])
print("September","|",d_20_21["September"])

#print(d_19_20)

f1.close()
# Out:
# Month  |  Difference
# --------|------------
# January | 182
# February | 213
# March | -65
# April | -257
# May | -145
# June | -156
# July | -113
# August | -26
# September | -30
